# %%
#Q1
import matplotlib.pyplot as plt
import numpy as np
import string

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])
print(A)

# 3x3 Identity transformation matrix
I = np.eye(3) #float
print(I)

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    output_row = I @ row
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()
# Out:
# [[ 0  1  0]
#  [ 1  0  1]
#  [ 0 -1  2]
#  [-1  0  3]]
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# # Question 2(i) scaling transformation with scale of 2

# %%
#Question 2(i) scaling transformation with scale of 2

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])


# 3x3 Identity transformation matrix
I = np.eye(3) #float

#Scaling matrix, Each point m
S = np.zeros((3,3),float)
np.fill_diagonal(S,2)
S[2][2] = 1
print(S)

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
   
    #output_row = np.matmul(S,row)
    output_row = S @ row
    #print(output_row)
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
#print(xs)
#print(ys)
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()
# Out:
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# # Question 2(ii) rotation transformation with 90 deg

# %%
import math
# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])




#Rotation martrix 90 deg clockwise
#math.pi / 2 == 1.57 rad == 90 degree
R = np.array([[np.cos(math.pi/2),np.sin(math.pi/2),0.0],
             [-np.sin(math.pi/2),np.cos(math.pi/2),0.0],
             [0.0,0.0,1.0]])
print(R)

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #Each row multiply with the rotation matrix
    #output_row = np.matmul(R,row)
    output_row = R @ row
    #print(output_row)
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")

xs.append(xs[0])
ys.append(ys[0])

plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()
# Out:
# [[ 6.123234e-17  1.000000e+00  0.000000e+00]
#  [-1.000000e+00  6.123234e-17  0.000000e+00]
#  [ 0.000000e+00  0.000000e+00  1.000000e+00]]

# %% [markdown]
# # Question 2(iii) Translation transformation,horizontal shear and vertical shear using your own parameters.

# %%
import math
# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])


#Translation
T = np.zeros((3,3),float)
np.fill_diagonal(T,1)
T[0][2] = 2
T[1][2] = 2
print(T)

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #Each row multiply with the Translation matrix
    output_row = T @ row
    print(output_row)
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")

xs.append(xs[0])
ys.append(ys[0])

plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-1, 7, 0.5))
ax.set_yticks(np.arange(-1, 7, 0.5))
plt.grid()
plt.show()
# Out:
# [[1. 0. 2.]
#  [0. 1. 2.]
#  [0. 0. 1.]]
# [0. 1. 0.]
# [3. 2. 1.]
# [4. 3. 2.]
# [5. 6. 3.]

# %%
import math
# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])


#Horizontal Shear
H = np.zeros((3,3),float)
np.fill_diagonal(H,1)
H[0][1] = 3
print(H)
color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #Each row multiply with the HorizontaL shear matrix
    output_row = H @ row
    print(output_row)
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")

xs.append(xs[0])
ys.append(ys[0])

plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-1, 4, 0.5))
ax.set_yticks(np.arange(-1, 4, 0.5))
plt.grid()
plt.show()
# Out:
# [[1. 3. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [3. 1. 0.]
# [1. 0. 1.]
# [-3. -1.  2.]
# [-1.  0.  3.]

# %%
import math
# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])


#Vertical Shear
V = np.zeros((3,3),float)
np.fill_diagonal(V,1)
V[1][0] = 3
print(V)


color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #Each row multiply with the Vertivle shear matrix
    output_row = V @ row
    print(output_row)
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")

xs.append(xs[0])
ys.append(ys[0])

plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2, 4, 0.5))
ax.set_yticks(np.arange(-3, 4, 0.5))
plt.grid()
plt.show()
# Out:
# [[1. 0. 0.]
#  [3. 1. 0.]
#  [0. 0. 1.]]
# [0. 1. 0.]
# [1. 3. 1.]
# [ 0. -1.  2.]
# [-1. -3.  3.]

# %% [markdown]
# # Question 3:implement a combination of the rotation and scaling transformations, i.e., a rotation followed by scaling

# %%
import math
# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])



# 3x3 Identity transformation matrix
I = np.eye(3) #float

#Rotation martrix 90 deg clockwise
#math.pi / 2 == 1.57 rad == 90 degree
R = np.array([[np.cos(math.pi/2),np.sin(math.pi/2),0.0],
             [-np.sin(math.pi/2),np.cos(math.pi/2),0.0],
             [0.0,0.0,1.0]])
#print(R)

#Translation
T = np.zeros((3,3),float)
np.fill_diagonal(T,1)
T[0][2] = 2
T[1][2] = 0
#print(T)


#Horizontal Shear
H = np.zeros((3,3),float)
np.fill_diagonal(H,1)
H[0][1] = 3


#Vertical Shear
V = np.zeros((3,3),float)
np.fill_diagonal(V,1)
V[1][0] = 3


color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    '''Note that since the transformations are linear, a combination of
transformations is represented simply as a product of the matrices representing the individual
transformation.'''
    output_row = S @ row  #scale each row by 2
    output_row = R @ output_row #rotate each row 90 deg
    output_row = V @ output_row 
    print(output_row)
    x, y, i = output_row
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")

xs.append(xs[0])
ys.append(ys[0])

plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-4, 8, 0.5))
ax.set_yticks(np.arange(-4, 8, 0.5))
plt.grid()
plt.show()
# Out:
# [2. 6. 0.]
# [ 1.2246468e-16 -2.0000000e+00  1.0000000e+00]
# [-2. -6.  2.]
# [-1.2246468e-16  2.0000000e+00  3.0000000e+00]
